# %%
## Donwload dataset from g drive

# %%
import gdown
url = 'https://drive.google.com/file/d/1mhudMSTodMYPEOp2QRJV0M7Ld3hfo1V-/view?usp=sharing'

# %%
file_id=url.split('/')[-2]
file_id
# Out:
# '1mhudMSTodMYPEOp2QRJV0M7Ld3hfo1V-'

# %%
prefix='https://drive.google.com/uc?export=download&id='
gdown.download(prefix+file_id,'kidney_disease.zip',quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1mhudMSTodMYPEOp2QRJV0M7Ld3hfo1V-
# From (redirected): https://drive.google.com/uc?export=download&id=1mhudMSTodMYPEOp2QRJV0M7Ld3hfo1V-&confirm=t&uuid=f91d1923-2d1d-4594-ad0e-30096d40909c
# To: d:\Kidney-Disease-classification-cnn\research\kidney_disease.zip
# 100%|██████████| 940M/940M [10:18<00:00, 1.52MB/s]
# 'kidney_disease.zip'
