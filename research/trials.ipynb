# %%
## Donwload dataset from g drive

# %%
import gdown
url = 'https://drive.google.com/file/d/15AWxlgsbETlz277Hqc_9bt39EqIuwfNj/view?usp=sharing'

# %%
file_id=url.split('/')[-2]
file_id
# Out:
# '15AWxlgsbETlz277Hqc_9bt39EqIuwfNj'

# %%
prefix='https://drive.google.com/uc?export=download&id='
gdown.download(prefix+file_id,'kidney_disease.zip',quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=15AWxlgsbETlz277Hqc_9bt39EqIuwfNj
# From (redirected): https://drive.google.com/uc?export=download&id=15AWxlgsbETlz277Hqc_9bt39EqIuwfNj&confirm=t&uuid=eabb6147-7c51-4e92-a206-0a4439e694e4
# To: d:\Kidney-Disease-classification-cnn\research\kidney_disease.zip
# 100%|██████████| 940M/940M [36:21<00:00, 431kB/s]
# 'kidney_disease.zip'
